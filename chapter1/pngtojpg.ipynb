# %%
#convert image from png to jpg using OpenCV
import cv2
import matplotlib.pyplot as plt
import sys
pngImage= cv2.imread('wolf-8142720_1920.png')
if pngImage is None:
    print("Error: Could not read the image.")
    sys.exit(1)
jpgImage = cv2.imwrite('wolf-8142720_1920.jpg', pngImage)
if not jpgImage:
    print("Error: Could not write the image.")
    sys.exit(1) 
# Display the original and converted images
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(pngImage, cv2.COLOR_BGR2RGB))
plt.title('Original PNG Image')
plt.axis('off')
plt.subplot(1, 2, 2)
jpgImage = cv2.imread('wolf-8142720_1920.jpg')
plt.imshow(cv2.cvtColor(jpgImage, cv2.COLOR_BGR2RGB))
plt.title('Converted JPG Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1334.5), np.float64(-0.5))
