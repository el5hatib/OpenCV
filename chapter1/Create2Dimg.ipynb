# %%
#create 2D black image with numpy and openCV
import numpy as np
import cv2
import matplotlib.pyplot as plt
image=np.zeros((512, 512, 3), np.uint8) 
#display the image
plt.imshow(image)
plt.axis('off')  # Hide the axes
plt.show()  # Show the image
